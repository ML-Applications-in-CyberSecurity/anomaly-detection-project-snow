# %% [markdown]
# ### 🧩 Imports
#
# Import all the necessary libraries:
# - `json` for reading/writing JSON files.
# - `pandas` and `numpy` for data manipulation.
# - `random` for generating random synthetic data.
# - `IsolationForest` from `sklearn` for anomaly detection.
# - `joblib` for saving the trained model.

# %%
import json
import pandas as pd
from sklearn.ensemble import IsolationForest
import numpy as np
import random
import joblib
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### 📊 Generate Dataset
#
# Create synthetic "normal" network traffic data to train an anomaly detection model. Each sample includes:
#
# - `src_port`: randomly selected from common service ports.
# - `dst_port`: a random high port number.
# - `packet_size`: typical packet sizes.
# - `duration_ms`: duration of the communication.
# - `protocol`: randomly selected between TCP and UDP.
#
# This data is saved to `training_data.json` for future use.

# %%
COMMON_PORTS = [80, 443, 22, 8080]
PROTOCOLS = ["TCP", "UDP"]

def generate_normal_data():
    return {
        "src_port": random.choice(COMMON_PORTS),
        "dst_port": random.randint(1024, 65535),
        "packet_size": random.randint(100, 1500),
        "duration_ms": random.randint(50, 500),
        "protocol": random.choice(PROTOCOLS)
    }

dataset = [generate_normal_data() for _ in range(1000)]
df = pd.DataFrame(dataset)

# %%
df
# Out:
#      src_port  dst_port  packet_size  duration_ms protocol
# 0          80     53834          390          486      UDP
# 1          22     27834          529           63      UDP
# 2         443     38060         1088          202      TCP
# 3          22     13309          798          107      TCP
# 4          22      3613          616          330      UDP
# ..        ...       ...          ...          ...      ...
# 995      8080     32512          528          140      TCP
# 996       443     22870         1328          382      UDP
# 997        22     59127          294          229      UDP
# 998        22     14891         1392          417      UDP
# 999        22     18856          580          489      UDP
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### 🧼 Preprocessing Function
#
# Machine learning models like Isolation Forest require **numerical input only**. Any categorical variables, such as the `protocol` column (`TCP`, `UDP`), must be converted into numbers.
#
# We handle this by **mapping categorical values to numerical representations**.
#
# #### 🛠️ Preprocessing Steps:
#
# 1.  **Identify categorical columns**:
#     * In our case, the `protocol` column is categorical (`TCP`, `UDP`, `ICMP`, `UNKNOWN`).
#
# 2.  **Use direct mapping**:
#     * We assign a unique numerical value to each protocol type.
#     * For instance:
#         * `'TCP'` maps to `0`
#         * `'UDP'` maps to `1`
#         * `'ICMP'` maps to `2`
#         * `'UNKNOWN'` maps to `3`
#     * This conversion ensures that the `protocol` column becomes a numerical feature that the model can process.
#
# 3.  **Return a DataFrame with all numerical values**:
#     * This DataFrame is now ready for model input.
#
# > ✅ This preprocessing is essential to avoid errors during training and ensure the model can learn from categorical variables.

# %%
protocol_map = {'TCP': 0, 'UDP': 1, 'ICMP': 2, 'UNKNOWN': 3}
df['protocol'] = df['protocol'].map(protocol_map)

# %%
df
# Out:
#      src_port  dst_port  packet_size  duration_ms  protocol
# 0          80     53834          390          486         1
# 1          22     27834          529           63         1
# 2         443     38060         1088          202         0
# 3          22     13309          798          107         0
# 4          22      3613          616          330         1
# ..        ...       ...          ...          ...       ...
# 995      8080     32512          528          140         0
# 996       443     22870         1328          382         1
# 997        22     59127          294          229         1
# 998        22     14891         1392          417         1
# 999        22     18856          580          489         1
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### 🤖 Train Isolation Forest
#
# The `IsolationForest` algorithm is an unsupervised model used to detect anomalies. It isolates observations by randomly selecting features and splitting values.
#
# - `n_estimators=100`: number of trees in the forest.
# - `contamination=0.2`: assumes 20% of the data is anomalous (based on the expected anomaly rate from the server.)
# - `random_state=42`: ensures reproducibility.
#
# The model is trained on the preprocessed numerical dataset.

# %%
model = IsolationForest(contamination=0.2, random_state=42)
model.fit(df)
# Out:
# IsolationForest(contamination=0.2, random_state=42)

# %% [markdown]
# ### 📊 Visualization of Normal vs. Anomaly Points using PCA
#
# To visualize the distribution of normal and anomalous data points, we first need to reduce the dimensionality of our sensor data. Since our data has multiple features (like `src_port`, `dst_port`, `packet_size`, etc.), directly plotting them in 2D or 3D is not straightforward.
#
# **Principal Component Analysis (PCA)** is a powerful dimensionality reduction technique that transforms the data into a new coordinate system, where the first few dimensions (principal components) capture the maximum variance in the data. This allows us to represent high-dimensional data in a lower-dimensional space (e.g., 2D or 3D) while retaining most of the important information.
#
# Here's how we apply PCA and visualize the results:
#
# 1.  **Dimensionality Reduction:** We reduce the sensor data to 2 principal components using `sklearn.decomposition.PCA`.
# 2.  **Anomaly Prediction on Training Data:** We use our trained `IsolationForest` model to predict which of the training data points are normal (labeled `1`) and which are anomalies (labeled `-1`).
# 3.  **Scatter Plot:** We then create a scatter plot where each point represents a data instance in the 2D PCA space. Normal points are colored blue, and detected anomalies are colored red. This visualization helps us understand how well the Isolation Forest algorithm separates the anomalies from the normal data.

# %%
pca = PCA(n_components=2)
df_2d = pca.fit_transform(df)

df_predictions = model.predict(df)

normal_points_2d = df_2d[df_predictions == 1]
anomaly_points_2d = df_2d[df_predictions == -1]

plt.figure(figsize=(10, 8))
plt.scatter(normal_points_2d[:, 0], normal_points_2d[:, 1], color='blue', label='Normal', alpha=0.6)
plt.scatter(anomaly_points_2d[:, 0], anomaly_points_2d[:, 1], color='red', label='Anomaly', alpha=0.8)

plt.title('2D PCA Visualization of Normal vs. Anomaly Points')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.savefig('anomaly_visualization_pca.png')
# plt.show()

# %% [markdown]
# ### 💾 Save Trained Model
#
# Save the trained model using `joblib`, which allows for efficient serialization and deserialization. This saved model can be reused later for inference or deployment.

# %%
joblib.dump(model, "anomaly_model.joblib")
# Out:
# ['anomaly_model.joblib']

# %% [markdown]
# # predict data

# %%
model.predict(df.iloc[[0]])
# Out:
# array([1])
