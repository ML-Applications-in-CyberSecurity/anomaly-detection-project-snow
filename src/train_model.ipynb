# %% [markdown]
# ### 🧩 Imports
#
# Import all the necessary libraries:
#
# - `json` for reading/writing JSON files.
# - `pandas` and `numpy` for data manipulation and numerical operations.
# - `random` for generating random synthetic data.
# - `IsolationForest` from `sklearn` for anomaly detection.
# - `joblib` for saving and loading the trained model.
# - `matplotlib.pyplot` for visualization.
# - `PCA` from `sklearn.decomposition` for dimensionality reduction and visualization of high-dimensional data.

# %%
import json
import pandas as pd
from sklearn.ensemble import IsolationForest
import numpy as np
import random
import joblib
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### 📊 Generate Dataset
#
# Create synthetic "normal" network traffic data to train an anomaly detection model. Each sample includes:
#
# - `src_port`: randomly selected from common service ports.
# - `dst_port`: a random high port number (1024-65535).
# - `packet_size`: typical packet sizes in bytes.
# - `duration_ms`: duration of the communication in milliseconds.
# - `protocol`: randomly selected between TCP and UDP.
#
# This data is saved to `training_data.json` for future use.

# %%
COMMON_PORTS = [80, 443, 22, 8080]
PROTOCOLS = ["TCP", "UDP"]

def generate_normal_data():
    return {
        "src_port": random.choice(COMMON_PORTS),
        "dst_port": random.randint(1024, 65535),
        "packet_size": random.randint(100, 1500),
        "duration_ms": random.randint(50, 500),
        "protocol": random.choice(PROTOCOLS)
    }

# Generate 1000 samples of normal network traffic data
dataset = [generate_normal_data() for _ in range(1000)]

# Convert to DataFrame for easier manipulation
df = pd.DataFrame(dataset)

# Save dataset to JSON file for reproducibility and later use
df.to_json("training_data.json", orient="records", lines=True)

# %% [markdown]
# ### 🗂️ Generating More Complex Synthetic Normal Data
#
# To make our anomaly detection model more robust and realistic, we're generating synthetic "normal" sensor data with more intricate patterns and relationships, rather than just simple uniform random values. This helps the Isolation Forest model learn a more nuanced understanding of "normal" behavior, improving its ability to identify true anomalies.
#
# Here's how the `generate_normal_data()` function has been enhanced:
#
# - **Protocol-Specific Distributions:**
#   - For `TCP` traffic, `packet_size` and `duration_ms` are generated from normal distributions with higher means, reflecting typically larger and longer-lasting packets.
#   - For `UDP` traffic, these values are generated from normal distributions with lower means, as UDP packets are generally smaller and quicker. Specific common UDP ports (like DNS, NTP) are also used for `src_port`.
#
# - **Feature Correlation:**
#   - A subtle positive correlation is introduced between `packet_size` and `duration_ms` for TCP traffic. This means that larger packets tend to have slightly longer durations, mimicking real-world network behavior.
#
# - **Normal Distributions with Noise:**
#   - Instead of uniform random integers (`random.randint`), we now use `numpy.random.normal()` to generate values. This creates a more natural, bell-curve-like distribution around a mean, with a specified standard deviation, and includes some inherent "noise" for realism.
#
# - **Value Clamping:**
#   - `np.clip()` is used to ensure that generated values remain within sensible, physical bounds (e.g., packet sizes don't become negative or excessively large).
#
# This enhanced data generation ensures our training data more closely resembles the complexity found in real-world network traffic, allowing our Isolation Forest model to develop a more sophisticated baseline for normal behavior. The generated data is then compiled into a Pandas DataFrame for further preprocessing and model training.

# %%
COMMON_PORTS = [80, 443, 22, 8080]
UDP_PORTS = [53, 123, 161]
PROTOCOLS = ["TCP", "UDP"]

def generate_normal_data():
    protocol = random.choice(PROTOCOLS)

    if protocol == "TCP":
        src_port = random.choice(COMMON_PORTS)
        dst_port = random.randint(1024, 65535)
        packet_size = int(np.clip(np.random.normal(800, 100), 100, 1500))
        duration_ms = int(np.clip(np.random.normal(300 + (packet_size * 0.02), 30), 50, 1000))

    elif protocol == "UDP":
        src_port = random.choice(UDP_PORTS)
        dst_port = random.randint(1024, 65535)
        packet_size = int(np.clip(np.random.normal(200, 50), 50, 800))
        duration_ms = int(np.clip(np.random.normal(100, 20), 20, 400))

    return {
        "src_port": src_port,
        "dst_port": dst_port,
        "packet_size": packet_size,
        "duration_ms": duration_ms,
        "protocol": protocol
    }

dataset = [generate_normal_data() for _ in range(2000)]
df = pd.DataFrame(dataset)

# %%
# COMMON_PORTS = [80, 443, 22, 8080]
# PROTOCOLS = ["TCP", "UDP"]
#
# def generate_normal_data():
#     """
#     Generates a single synthetic normal sensor data point with more complex patterns.
#     Includes correlated features and protocol-specific distributions.
#     """
#     protocol = random.choice(PROTOCOLS)
#
#     # Base values (mean and std dev for normal distribution)
#     base_packet_size_tcp_mean = 700
#     base_packet_size_udp_mean = 150
#     base_duration_tcp_mean = 300
#     base_duration_udp_mean = 80
#
#     std_dev_packet = 100
#     std_dev_duration = 30
#
#     if protocol == "TCP":
#         src_port = random.choice(COMMON_PORTS)
#         dst_port = random.randint(1024, 65535)
#
#         # Generate packet size from a normal distribution for TCP
#         packet_size = int(np.random.normal(base_packet_size_tcp_mean, std_dev_packet))
#
#         # Generate duration with some correlation to packet_size
#         # Larger packets might take slightly longer, add some noise
#         duration_ms = int(np.random.normal(base_duration_tcp_mean, std_dev_duration) + (packet_size * 0.05))
#
#         # Ensure values are within reasonable bounds
#         packet_size = max(100, min(1500, packet_size)) # Clamp values
#         duration_ms = max(50, min(1000, duration_ms)) # Allow slightly longer durations for TCP
#
#     elif protocol == "UDP":
#         # UDP specific common ports (e.g., DNS, NTP, SNMP)
#         src_port = random.choice([53, 123, 161])
#         dst_port = random.randint(1024, 65535)
#
#         # Generate packet size from a normal distribution for UDP (smaller packets)
#         packet_size = int(np.random.normal(base_packet_size_udp_mean, std_dev_packet * 0.5))
#
#         # Generate duration for UDP (usually shorter)
#         duration_ms = int(np.random.normal(base_duration_udp_mean, std_dev_duration * 0.5))
#
#         # Ensure values are within reasonable bounds
#         packet_size = max(50, min(800, packet_size))
#         duration_ms = max(20, min(400, duration_ms))
#
#     else: # Fallback for unexpected protocols (though PROTOCOLS only contains TCP/UDP now)
#         src_port = random.choice(COMMON_PORTS)
#         dst_port = random.randint(1024, 65535)
#         packet_size = random.randint(100, 1500)
#         duration_ms = random.randint(50, 500)
#
#     return {
#         "src_port": src_port,
#         "dst_port": dst_port,
#         "packet_size": packet_size,
#         "duration_ms": duration_ms,
#         "protocol": protocol
#     }
#
# dataset = [generate_normal_data() for _ in range(1000)]
# df = pd.DataFrame(dataset)

# %%
df
# Out:
#       src_port  dst_port  packet_size  duration_ms protocol
# 0           22     60361          943          317      TCP
# 1          161     54687          120           63      UDP
# 2          443     46828          826          284      TCP
# 3          161     24589          280           70      UDP
# 4          123     58925          223           97      UDP
# ...        ...       ...          ...          ...      ...
# 1995       443      9460          662          365      TCP
# 1996        22      8358          767          296      TCP
# 1997      8080     14614          801          316      TCP
# 1998        53     28467          218          102      UDP
# 1999      8080     39195          958          297      TCP
#
# [2000 rows x 5 columns]

# %% [markdown]
# ### 🧼 Preprocessing Function
#
# Machine learning models like Isolation Forest require **numerical input only**. Any categorical variables, such as the `protocol` column (`TCP`, `UDP`), must be converted into numbers.
#
# We handle this by **mapping categorical values to numerical representations**.
#
# #### 🛠️ Preprocessing Steps:
#
# 1. **Identify categorical columns**:
#    - In our case, the `protocol` column is categorical (`TCP`, `UDP`, `ICMP`, `UNKNOWN`).
#
# 2. **Use direct mapping**:
#    - We assign a unique numerical value to each protocol type.
#    - For instance:
#      - `'TCP'` maps to `0`
#      - `'UDP'` maps to `1`
#      - `'ICMP'` maps to `2`
#      - `'UNKNOWN'` maps to `3`
#    - This conversion ensures that the `protocol` column becomes a numerical feature that the model can process.
#
# 3. **Return a DataFrame with all numerical values**:
#    - This DataFrame is now ready for model input.
#
# > ✅ This preprocessing is essential to avoid errors during training and ensure the model can learn from categorical variables.

# %%
protocol_map = {'TCP': 0, 'UDP': 1, 'ICMP': 2, 'UNKNOWN': 3}
def preprocess_data(df):
    print(df['protocol'])
    df_processed = df.copy()
    print(df_processed['protocol'])
    df_processed['protocol'] = df_processed['protocol'].astype(str).str.strip().str.upper()
    df_processed['protocol'] = df_processed['protocol'].map(protocol_map).fillna(3).astype(int)
    return df_processed

df = preprocess_data(df)
print(df.head())
# Out:
# 0       TCP
# 1       UDP
# 2       TCP
# 3       UDP
# 4       UDP
#        ...
# 1995    TCP
# 1996    TCP
# 1997    TCP
# 1998    UDP
# 1999    TCP
# Name: protocol, Length: 2000, dtype: object
# 0       TCP
# 1       UDP
# 2       TCP
# 3       UDP
# 4       UDP
#        ...
# 1995    TCP
# 1996    TCP
# 1997    TCP
# 1998    UDP
# 1999    TCP
# Name: protocol, Length: 2000, dtype: object
#    src_port  dst_port  packet_size  duration_ms  protocol
# 0        22     60361          943          317         0
# 1       161     54687          120           63         1
# 2       443     46828          826          284         0
# 3       161     24589          280           70         1
# 4       123     58925          223           97         1

# %%
df
# Out:
#       src_port  dst_port  packet_size  duration_ms  protocol
# 0           22     60361          943          317         0
# 1          161     54687          120           63         1
# 2          443     46828          826          284         0
# 3          161     24589          280           70         1
# 4          123     58925          223           97         1
# ...        ...       ...          ...          ...       ...
# 1995       443      9460          662          365         0
# 1996        22      8358          767          296         0
# 1997      8080     14614          801          316         0
# 1998        53     28467          218          102         1
# 1999      8080     39195          958          297         0
#
# [2000 rows x 5 columns]

# %% [markdown]
# ### 🤖 Train Isolation Forest
#
# The `IsolationForest` algorithm is an unsupervised model used to detect anomalies. It isolates observations by randomly selecting features and splitting values.
#
# - `n_estimators=100`: number of trees in the forest (default).
# - `contamination=0.01`: assumes about 1% of the data is anomalous.
# - `random_state=42`: ensures reproducibility.
#
# The model is trained on the **preprocessed** and **scaled numerical dataset**.
#
# We also use `StandardScaler` to normalize the features, which helps the model converge better and improves performance.
#
# After training, both the model and the scaler are saved using `joblib` for later use.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest
import joblib

# Preprocess data (protocol mapping)
df_processed = preprocess_data(df)

# Scale features to zero mean and unit variance
scaler = StandardScaler()
scaled_array = scaler.fit_transform(df_processed)
scaled_df = pd.DataFrame(scaled_array, columns=df_processed.columns)

# Train Isolation Forest model
model = IsolationForest(contamination=0.01, random_state=42)
model.fit(scaled_df)

# Save the model and scaler to disk for later inference
joblib.dump(model, "anomaly_model.joblib")
joblib.dump(scaler, "scaler.joblib")
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    1
# 1999    0
# Name: protocol, Length: 2000, dtype: int64
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    1
# 1999    0
# Name: protocol, Length: 2000, dtype: int64
# ['scaler.joblib']

# %% [markdown]
# ### 📊 Visualization of Normal vs. Anomaly Points using PCA
#
# To visualize the distribution of normal and anomalous data points, we reduce the dimensionality of the sensor data using **Principal Component Analysis (PCA)**.
#
# - PCA transforms the original high-dimensional feature space into a lower-dimensional space (2D here), preserving the most variance.
# - This allows us to plot complex data and observe clustering or separation visually.
# - Using our trained `IsolationForest` model, we label points as normal (`1`) or anomaly (`-1`).
# - Finally, we scatter plot the 2D points, coloring anomalies in red and normal points in blue.
#
# This visualization gives an intuitive understanding of how well the model distinguishes anomalies.

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Apply PCA to reduce to 2 components
pca = PCA(n_components=2)
df_2d = pca.fit_transform(scaled_df)

# Predict anomalies on training data
df_predictions = model.predict(scaled_df)

# Separate normal and anomaly points
normal_points_2d = df_2d[df_predictions == 1]
anomaly_points_2d = df_2d[df_predictions == -1]

# Plot
plt.figure(figsize=(10, 8))
plt.scatter(normal_points_2d[:, 0], normal_points_2d[:, 1], color='blue', label='Normal', alpha=0.6)
plt.scatter(anomaly_points_2d[:, 0], anomaly_points_2d[:, 1], color='red', label='Anomaly', alpha=0.8)

plt.title('2D PCA Visualization of Normal vs. Anomaly Points')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

# Save figure for reports or presentations
plt.savefig('anomaly_visualization_pca.png')

# Optional: Uncomment the next line if you want to display plot inline in notebooks or scripts
# plt.show()

# %% [markdown]
# ### 💾 Save Trained Model
#
# Save the trained model using `joblib`, which allows for efficient serialization and deserialization. This saved model can be reused later for inference or deployment.

# %%
joblib.dump(model, "anomaly_model.joblib")
# Out:
# ['anomaly_model.joblib']

# %% [markdown]
# ### 🔍 Predicting Anomaly for a Single Data Row
#
# To predict whether a single data instance is anomalous or normal using the trained Isolation Forest model, we need to:
#
# 1. Select the row from the original DataFrame.
# 2. Preprocess it exactly like the training data (including scaling).
# 3. Pass the processed row to the model's `predict()` method.
#
# The model will return:
# - `1` for normal data
# - `-1` for anomaly

# %%
row = df.iloc[[0]]
row_scaled_array = scaler.transform(row)
row_scaled = pd.DataFrame(row_scaled_array, columns=row.columns)

model.predict(row_scaled)
# Out:
# array([1])
